# %%
import requests
import json
import geopandas as gpd

# %%
latitude = 53.31
longitude = -6.25

home_point = f'{str(longitude)}, {str(latitude)}'

# %% [markdown]
# ## Existing API Call

# %%
payload = {
    'f': 'geojson',
    'where': '1 = 1',
    'outSr': '4326',
    'geometryType': 'esriGeometryPoint',
    'outFields': '*',
    'inSr': '4326',
    'geometry': home_point,
    'distance': 1000,
    'orderByFields': 'ReceivedDate DESC',
}

response = requests.get(
        'https://services.arcgis.com/NzlPQPKn5QF9v2US/arcgis/rest/services/IrishPlanningApplications/FeatureServer/0/query',
        params=payload)

# %% [markdown]
# Executed in 1.45 seconds

# %%
# Get keys for application response
sorted(single_app['properties'].keys())
# Out:
# ['AppealDecision',
#  'AppealDecisionDate',
#  'AppealRefNumber',
#  'AppealStatus',
#  'AppealSubmittedDate',
#  'ApplicantAddress',
#  'ApplicantForename',
#  'ApplicantSurname',
#  'ApplicationNumber',
#  'ApplicationStatus',
#  'ApplicationType',
#  'AreaofSite',
#  'Decision',
#  'DecisionDate',
#  'DecisionDueDate',
#  'DevelopmentAddress',
#  'DevelopmentDescription',
#  'DevelopmentPostcode',
#  'ETL_DATE',
#  'ExpiryDate',
#  'FIRecDate',
#  'FIRequestDate',
#  'FloorArea',
#  'GrantDate',
#  'ITMEasting',
#  'ITMNorthing',
#  'LandUseCode',
#  'LinkAppDetails',
#  'NumResidentialUnits',
#  'OBJECTID',
#  'ORIG_FID',
#  'OneOffHouse',
#  'OneOffKPI',
#  'PlanningAuthority',
#  'ReceivedDate',
#  'SiteId',
#  'WithdrawnDate']

# %% [markdown]
# ## Updated API Call

# %%
api_out_fields = '''
ApplicationNumber,
ApplicationStatus,
Decision,
DevelopmentDescription,
LinkAppDetails,
PlanningAuthority,
ReceivedDate
'''

payload2 = {
    'f': 'geojson',
    'where': '1 = 1',
    'outSr': '4326',
    'geometryType': 'esriGeometryPoint',
    'outFields': api_out_fields,
    'inSr': '4326',
    'geometry': home_point,
    'distance': 1000,
    'orderByFields': 'ReceivedDate DESC',
}
response2 = requests.get(
        'https://services.arcgis.com/NzlPQPKn5QF9v2US/arcgis/rest/services/IrishPlanningApplications/FeatureServer/0/query',
        params=payload2)

# %%
response2.
# Out:
# <Response [200]>

# %%
response2.json()
# Out:
# {'type': 'FeatureCollection',
#  'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}},
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.25257563450668, 53.3116203889647]},
#    'properties': {'ApplicationNumber': '3170/20',
#     'ApplicationStatus': 'Registered Application',
#     'Decision': None,
#     'DevelopmentDescription': 'PROTECTED STRUCTURE:  Planning permission - the development will consist of the  demolition of a two-storey extension to the side; the construction of new two-storey extensions to  the side and rear; internal alterations to  the house and general refurbishment works.',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1596758400000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.25701426990403, 53.3174235114114]},
#    'properties': {'ApplicationNumber': '3150/20',
#     'ApplicationStatus': 'Registered Application',
#     'Decision': None,
#     'DevelopmentDescription': 'PROTECTED STRUCTURE: The proposed development shall provide for a new vehicular entrance; 1 car parking space; an electric vehicle charging point; and associated works including replacing concrete with pebbles to improve drainage; all within the front garden.',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1596672000000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.2572787286242, 53.3097038452464]},
#    'properties': {'ApplicationNumber': 'WEB1476/20',
#     'ApplicationStatus': 'Registered Application',
#     'Decision': None,
#     'DevelopmentDescription': 'The proposed development involves the division of a pair of semi-detached houses into two detached houses, by way of demolishing 1.58 m of the connecting structure, 24.4 sq.m of floor area of No. 56 alongside No 55. It is proposed to extend and convert the existing attic store area of 24sq.m to an area of 51sq.m. containing 2 bedrooms and a bathroom and to increase the height of the ridge in No. 55 by 975mm. There will be 2 new dormer windows to the rear serving the 2 bedrooms and a window and skylight to serve the bathroom. The existing ground and first floor of No 55 remains unchanged.\r\nPermission is also sought in No. 56 to construct a new basement of 97.5 sq.m to the side and rear, Ground level extension to side and rear of 123 sq. m incorporating Living room, Kitchen, Garage and study. First Floor extension of 75.9 sq.m to the rear and side, incorporating 4 No bedrooms, Bathrooms and laundry with 4 windows facing to the rear and 3 No. the side, Attic Level extension to rear and side of 63 sq.m incorporating 1 No bed room and bathroom 1 No dormer and 1 windows and two skylights facing to the rear.\r\nIt is proposed to increase the ridge height in No. 56 by 975mm to equal the new ridge in No. 55 there by bringing the new attic space in both houses to habitable standard.\r\nAccess to off street car parking will remain unchanged in both dwellings.\r\nThe floor area of No. 56 will increase from 140.52 sq. m. to 446.43 sq. m. Floor area in No.55 will increase from 174.23 sqm. to 225.43 sqm.',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1595376000000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.2572787286242, 53.3097038452464]},
#    'properties': {'ApplicationNumber': 'WEB1456/20',
#     'ApplicationStatus': 'Decision Notice Issued',
#     'Decision': 'APPLICATION DECLARED INVALID',
#     'DevelopmentDescription': 'The proposed development involves the division of a pair of semi-detached houses into two detached houses, by way of demolishing 1.58M of the connecting structure, 24.4 sq.m of floor area of No. 56 alongside no 55. It is proposed to extend and convert the existing attic store area of 24sq.m to an area of 51sq.m. containing 2 bedrooms and a bathroom and to increase the height of the ridge in No. 55 by 975mm. There will be 2 new dormer windows to the rear serving the 2 bedrooms and a window and skylight to serve the bathroom. The existing ground and first floor of No 55 remains unchanged. Permission is also sought in no. 56 to construct a new basement of 97.5 sq.m to the side and rear, Ground level extension to side and rear of 123 sq.m incorporating Living room, Kitchen, Garage and study. First Floor extension of 75.9 sq.m to the rear and side, incorporating 4 no bedrooms, Bathrooms and laundry with 4 windows facing to the rear and 3 no. the side, Attic Level extension to rear and side of 63 sq.m incorporating 1 no bed room and bathroom 1 no dormer and 1 windows and two skylights facing to the rear.\r\nIt is proposed to increase the ridge height in no. 56 by 975mm to equal the new ridge in no. 55 thereby bringing the new attic space in both houses to habitable standard.\r\nAccesses to off street car parking will remain unchanged in both dwellings.\r\nThe floor area of no. 56 will increase from 140.52 sq. m. to 446.43 sq. m.',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1594857600000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.2572787286242, 53.3097038452464]},
#    'properties': {'ApplicationNumber': 'WEB1419/20',
#     'ApplicationStatus': 'Decision Notice Issued',
#     'Decision': 'APPLICATION DECLARED INVALID',
#     'DevelopmentDescription': 'The proposed development involves the division of a pair of semi detached houses into two detached houses, increasing the height of the ridge in No 55 so as to convert the existing attic store of 24sq.m to an area of 51sq.m. containing 2 bedrooms and a bathroom, and increasing the ridge height in no. 56 to equal the ridge in no. 55 thereby bringing the new attic space in both houses to habitable standard. In addition to provide in no. 56 a new basement and extensions at ground and first floor level and attic level. Accesses to off street car parking will remain unchanged in both dwellings. The floor area of no. 56 will increase from 140.52 sq. m. to 446.43 sq.m.',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1593993600000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.25174077927928, 53.3152373295175]},
#    'properties': {'ApplicationNumber': 'WEB1402/20',
#     'ApplicationStatus': 'Registered Application',
#     'Decision': None,
#     'DevelopmentDescription': 'The development will consist of demolition and removal of an existing rear extension and conservatory, and existing outhouse/shed, construction of a new single story extension to the rear (west) of the dwelling serving a dining area, kitchen area and utility room with new rooflights over the dining and kitchen areas, alteration of the existing two storey extension to the side elevation (south), consisting of new W.C. and cloakroom at ground floor, extending the existing bedroom at first floor, with a new section of hipped roof proposed over, in lieu of the existing flat roof, with roof tiles to match existing main roof. Total additional floor area proposed, 64.4msq – 27.9msq at ground, 11.4msq at first and 25.1msq at attic level. Additional works include internal alterations, construction of attic storage and access, new rainwater goods, soffits and fascias to match existing, a new front door and side lights within the existing arched opening, and replacement of existing windows with new thermally efficient windows, and all associated site development works.',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1593561600000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.25729365260862, 53.3093136424322]},
#    'properties': {'ApplicationNumber': '2934/20',
#     'ApplicationStatus': 'Registered Application',
#     'Decision': None,
#     'DevelopmentDescription': 'The development will consist of: Demolition of: garage, stores and chimney to side; existing single-storey extension to rear. Construction of: 2-storey extension to side, single-storey extension to rear, dormer window to rear roof. Changes to: porch roof and window/door openings to front elevation. All associated drainage and landscaping works.',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1593388800000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.26400104606553, 53.3103094226798]},
#    'properties': {'ApplicationNumber': 'WEB1397/20',
#     'ApplicationStatus': 'Registered Application',
#     'Decision': None,
#     'DevelopmentDescription': "The development consists of alterations to existing roof to accommodate a rear  dormer, convert existing side garage/shed, new vehicular access off St Kevin's Park, retention permission sought for the existing access gate off St Kevin's Gardens and associated works.",
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1593388800000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.2412430596751, 53.3054333986696]},
#    'properties': {'ApplicationNumber': 'D20B/0182',
#     'ApplicationStatus': 'Registered Application',
#     'Decision': None,
#     'DevelopmentDescription': 'Permission for development. The development will consist of',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1593043200000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.25422639595797, 53.3146382169179]},
#    'properties': {'ApplicationNumber': '2860/20',
#     'ApplicationStatus': 'Decision Notice Issued',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'PROTECTED STRUCTURE: The development will consist of the remodelling of the rear elevation and roof profile to resolve the unsatisfactory ceiling height when accessing the attic level bedrooms and to extend the floor area by 15sqm to create a new en-suite bedroom to the rear. At first floor level the works involve the interchanging of the study and bathroom. Refurbishment of the existing slate roof and ancillary site works in connection with the building works. The property is a protected structure.',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1591920000000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.25179472180259, 53.3171194990826]},
#    'properties': {'ApplicationNumber': '2856/20',
#     'ApplicationStatus': 'Decision Notice Issued',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'Permission for development consisting of the creation of a new vehicular entrance and associated gates including for all associated site development works to the front of No. 38 Park Drive, Ranelagh, Dublin 6.',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1591920000000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.25964089561237, 53.3151400782534]},
#    'properties': {'ApplicationNumber': '2862/20',
#     'ApplicationStatus': 'Decision Notice Issued',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'The development will consist of: Demolition of existing lean-to garage extension to side. Construction of single storey flat roof extension to rear with parapet detail and 1no. rooflight. Construction of single storey extension to side with lean-to roof and 1no. rooflight. Proposed timber-clad gate to front elevation. 2no. roof lights to existing front roof facade and 1no. rooflight to rear roof facade. Proposed 1no. dormer window to the rear. Widen vehicular access, internal modifications and all ancillary works.',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1591920000000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.26058478869502, 53.3154267126971]},
#    'properties': {'ApplicationNumber': '2817/20',
#     'ApplicationStatus': 'Decision Notice Issued',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'Permission for a new vehicular access and off-street car parking to the front garden at 1 Palmerston Gardens, Rathmines, Dublin 6, D06Y 7PO.',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1591315200000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.23914569536212, 53.3070394355363]},
#    'properties': {'ApplicationNumber': 'D20A/0360',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'REQUEST ADDITIONAL INFORMATION          ',
#     'DevelopmentDescription': 'Permission for revised roofs to both side extensions, new',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1590537600000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.25701426990403, 53.3174235114114]},
#    'properties': {'ApplicationNumber': '2762/20',
#     'ApplicationStatus': 'Decision Notice Issued',
#     'Decision': 'APPLICATION DECLARED INVALID',
#     'DevelopmentDescription': 'PROTECTED STRUCTURE:  The proposed development shall provide for a new vehicular entrance (just over 2m wide); 1 car parking space of the minimum permissible size (c.5 x 2m); an electric vehicle charging point; and associated development works including replacement of existing concrete with pebbles to improve drainage in particular, all within the front garden and without disturbing any original features of the Protected Structure.',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1590537600000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.25518478086464, 53.3152705837224]},
#    'properties': {'ApplicationNumber': '2740/20',
#     'ApplicationStatus': 'Decision Notice Issued',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'PROTECTED STRUCTURE:  Planning Permission at this site at Lismoy, 8 Temple Gardens, Rathmines, Dublin 6, a Protected Structure, for development consisting of:  Demolition of the existing non-original single storey extensions to the rear and construct a new single storey extension containing a kitchen, dining and family room;  extend existing return from first to second floor level to create a new bathroom with a hipped roof.  Extend the existing garage to east of house and use it as a store.  Demolish existing wall and non-original outbuilding on the western side of the house and construct a new single storey garage with ancillary wc to the rear.  Internal alterations and refurbishment of the existing house including replumbing and rewiring, new opening from den to living room, block up door ope to den, block up non original wall ope to form door to utility room.  Internal dry lining of all external walls of the existing house.  2 no. new conservation rooflights to internal slope of rear hipped roof.  Refurbishment and repair / replacement where necessary of existing up and down timber sash windows and fitting of slim light double glazing.  Remove existing slates as required throughout and re-fix on new underlay felt.  Widen existing vehicular entrance to 3.6m and fit new electric gates to match existing using existing materials to extend gates.  Landscape of front and rear garden including the repair of boundaries where required with a gravel/paved area and flower beds to the front and a paved patio to the rear and all with ancillary site works.',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1590105600000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.25796147946183, 53.3166081974665]},
#    'properties': {'ApplicationNumber': '2736/20',
#     'ApplicationStatus': 'Decision Notice Issued',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': "PROTECTED STRUCTURE:  The development will consist of works to the existing dwelling. A Protected Structure, as follows:  At garden level: new insulated floor slab, internal wall insulation, widen existing openings at internal spine wall and rear facade, remove door to rear and instate window, remove non-original staircase, replace external door to front and door to understair, remove non-original studs and install new stud layout to form cloaks, shower room and kitchen-dining area.  At entrance level, reinstate doorway to front reception, remove draught screen, new partition layout at pantry to form wc;  At first floor:  remove non-original partitions and install new partitions to create walk-through wardrobe and ensuite;  At 3rd Landing:  replace section of stud;  At roof: relay roof to incorporate membrane under slates, lay all new valleys/flashings, install 1 no. new rooflight and new solar panels to inner roofs, replace existing rooflight;  To rear external:  remove external staircase, replace 2 no. timber doors at existing shed;  Generally:  remove external window bars, strip all plumbing/heating and electrical services and install all new systems, remove non-original fittings, install new fittings and re-decorate and any associated repairs and builder's works.",
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1590019200000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.24162204135664, 53.3043632249298]},
#    'properties': {'ApplicationNumber': 'D20A/0334',
#     'ApplicationStatus': 'Registered Application',
#     'Decision': None,
#     'DevelopmentDescription': 'Permission for the construction of a new 51 sqm two',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1589328000000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.26181419385619, 53.3151321526272]},
#    'properties': {'ApplicationNumber': '2691/20',
#     'ApplicationStatus': 'Decision Notice Issued',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'Planning permission is sought for partial demolition and construction of single and part two storey extension to the rear, alterations to side elevation including new gable wall, together with dormer window to rear of new attic conversion and all associated site works to end of terrace two storey dwelling.',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1589241600000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.25736234478409, 53.3088383945286]},
#    'properties': {'ApplicationNumber': 'WEB1214/20',
#     'ApplicationStatus': 'Decision Notice Issued',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'Alterations to existing detached single storey dwelling involving the demolition of chimney and single story flat roof structure to front, provision of new low level boundary walls to front, addition of a pitched roofed porch extension to front, conversion of existing attic space into bedrooms and bathrooms, construction of new dormer window to rear, addition of new windows to side gable wall with new rooflights to front and rear, alterations to windows and doors in existing rear extension, provision of bike shed to front, widening of existing vehicular entrance and all associated site works.',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1587513600000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.24569874691305, 53.3014934072341]},
#    'properties': {'ApplicationNumber': 'D20A/0296',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'REQUEST ADDITIONAL INFORMATION          ',
#     'DevelopmentDescription': 'Retention Permission is sought for 5 year temporary planning permission for a',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1587513600000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.24280577738014, 53.309374819773]},
#    'properties': {'ApplicationNumber': 'D20A/0273',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'REQUEST ADDITIONAL INFORMATION          ',
#     'DevelopmentDescription': 'Permission for ground floor side extension, which provides',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1585872000000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.25729311155416, 53.3094184374761]},
#    'properties': {'ApplicationNumber': '2598/20',
#     'ApplicationStatus': 'Decision Notice Issued',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'Permission to: \r\n(a ) Widen front vehicular entrance gateway & associated piers,\r\n(b) To incorporate a seating & patio area to front of the house on the existing driveway and all associated site works.\r\n',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1585526400000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.23848003746222, 53.3049549158223]},
#    'properties': {'ApplicationNumber': 'D20B/0096',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'Permission for the construction of a first floor extension over the existing',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1585180800000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.2465568596345, 53.3180723592701]},
#    'properties': {'ApplicationNumber': 'WEB1148/20',
#     'ApplicationStatus': 'Decision Notice Issued',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'Demolition of the existing two-storey rear return, construction of a new two storey extension to rear comprising ground floor kitchen extension with rooflights and new second storey bedroom and bathroom extension, new windows to front and rear and all associated landscaping and drainage works',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1584662400000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.244468963043, 53.3047430858782]},
#    'properties': {'ApplicationNumber': 'D20A/0212',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'GRANT PERMISSION                        ',
#     'DevelopmentDescription': 'Permission for development. The devlopemtn will consist of:',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1583971200000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.25637443026422, 53.3087014329533]},
#    'properties': {'ApplicationNumber': '2446/20',
#     'ApplicationStatus': 'Decision Notice Issued',
#     'Decision': 'GRANT RETENTION PERMISSION',
#     'DevelopmentDescription': 'RETENTION:  Permission for retention of single storey extension to front and side of existing house at 41 South Hill, Dartry, Dublin 6.',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1583798400000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.2465568596345, 53.3180723592701]},
#    'properties': {'ApplicationNumber': 'WEB1129/20',
#     'ApplicationStatus': 'Decision Notice Issued',
#     'Decision': 'APPLICATION DECLARED INVALID',
#     'DevelopmentDescription': 'Demolition of the existing two-storey rear return, construction of a new two storey extension to rear comprising ground floor kitchen extension with rooflights and new second storey bedroom and bathroom extension, new windows to front and rear and all associated landscaping and drainage works',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1583798400000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.24753413931492, 53.3121025916434]},
#    'properties': {'ApplicationNumber': 'WEB1120/20',
#     'ApplicationStatus': 'Decision Notice Issued',
#     'Decision': 'APPLICATION WITHDRAWN',
#     'DevelopmentDescription': 'The development will consist of the replacement of the existing south-facing Première internally illuminated 6.4m wide x 3.36m high advertising display (granted under Reg. Ref. WEB1003/19) on the Southern gable wall of No. 7 Geraldine Terrace  with 1 no. 6.44m wide x 3.39m high digital advertising display, to be positioned at 5.89m above ground level, minor enlargement of rubbing strip to 0.88m wide and 0.05m high, 9 no. ‘lighthouse’ bollards and all associated site works and services',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1583452800000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.24481670001497, 53.3047140015083]},
#    'properties': {'ApplicationNumber': 'D20A/0179',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'GRANT PERMISSION                        ',
#     'DevelopmentDescription': 'Permission is sought for the development.  The development will consist of:',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1583280000000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.25637443026422, 53.3087014329533]},
#    'properties': {'ApplicationNumber': 'WEB1098/20',
#     'ApplicationStatus': 'Decision Notice Issued',
#     'Decision': 'APPLICATION DECLARED INVALID',
#     'DevelopmentDescription': 'RETENTION: Retention of single storey extensions to front and side of house.',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1582848000000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.25103633580141, 53.3182156806462]},
#    'properties': {'ApplicationNumber': 'WEB1092/20',
#     'ApplicationStatus': 'Decision Notice Issued',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'A single storey extension to the rear with flat roof over for extended living accommodation.',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1582675200000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.25637443026422, 53.3087014329533]},
#    'properties': {'ApplicationNumber': 'WEB1086/20',
#     'ApplicationStatus': 'Decision Notice Issued',
#     'Decision': 'APPLICATION DECLARED INVALID',
#     'DevelopmentDescription': 'RETENTION: Retention of single storey extensions to the front and side of existing house.',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1582243200000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.24710118140123, 53.3138846086478]},
#    'properties': {'ApplicationNumber': '2284/20',
#     'ApplicationStatus': 'Decision Notice Issued',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'The erection of new railings, entrance gates and new entrance piers at the existing access point located along the northern boundary along with all other ancillary development works on their lands at 1 Glenmalure Square, Milltown, Dublin 6.',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1581897600000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.25823184631302, 53.317059513591]},
#    'properties': {'ApplicationNumber': '2252/20',
#     'ApplicationStatus': 'Decision Notice Issued',
#     'Decision': 'GRANT PERMISSION AND RETENTION PERMISSION',
#     'DevelopmentDescription': 'PROTECTED STRUCTURE: RETENTION & PERMISSION: for development and for permission for development, for the retention of development and for works at a site of c. 414 sq m, located at No. 52, Palmerston Road, Rathmines, Dublin 6, D06 R2E7. (No. 52 Palmerston Road is designated a Protected Structure (RPS Ref. No. 6223 under the Dublin City Development Plan 2016-2022).) The development for which retention permission for development is sought consists of the following: retention of an additional 15.3 sq m of development (at basement/garden level, ground and mezzanine floor levels) beyond that permitted by condition no.1 of An Bord Pleanala decision PL29S.110594 of 1 September 1999 (Dublin Corporation Reg. Ref. 3655/98). The development for which permission for development is sought will consist of the: reconfiguration of part of the existing (non-original) rear extension at basement/garden level to reconfigure the kitchen/dining area and utility room; replacement of a store at ground floor level by a bathroom; partial removal/addition of internal walls and associated refurbishment works; all hard and soft landscaping including the provision of an external planter to the rear extension; and all other associated site development works above and below ground . The proposed development does not involve any change in the gross floor area of the structure (388 sq m).',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1581465600000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.23827714431902, 53.3049637912613]},
#    'properties': {'ApplicationNumber': 'D20A/0103',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'GRANT PERMISSION                        ',
#     'DevelopmentDescription': 'Permission for development which will consist of the',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1581292800000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.25676775020613, 53.3087555004]},
#    'properties': {'ApplicationNumber': 'WEB1061/20',
#     'ApplicationStatus': 'Decision Notice Issued',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'On behalf of Aisling and Shane Barrett, Planning Permission is sought for works at 43 South Hill, Dartry, Dublin, D06 Y0E0. Works to include the installation of external insulation, the demolition of a section of the existing entrance wall, increasing the existing driveway entrance. These are proposed in conjunction with the previous planning application of no. WEB1745/19. Works to also include all associated site and landscaping works.',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1581033600000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.26036372793024, 53.3157441239922]},
#    'properties': {'ApplicationNumber': '2210/20',
#     'ApplicationStatus': 'Decision Notice Issued',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'The development will consist of the widening of the existing front entrance gates, the associated dishing of the pavement and removal of the on-street parking for the reinstatement of vehicular access to the front, the addition of 2 new windows on the side elevation at first floor, ancillary works and site works to facilitate the development.',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1580947200000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.26190413784158, 53.3096477034678]},
#    'properties': {'ApplicationNumber': '2199/20',
#     'ApplicationStatus': 'Decision Notice Issued',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'PROTECTED STRUCTURE: Planning permission is sought for: construction of single storey rear extension 19.3 sqm, existing lower ground floor window to rear to be replaced with door, existing double doors to rear lower ground floor to be removed and ope widened to 2500mm to provide access to new extension wall between lower ground floor room and staircase to be removed, side (north) wall to rear return to be removed at lower ground floor level, construction of new stud work with double doors between lower ground floor front hall and proposed family room, provision of shower room with Velux window above top landing level, Velux window to inner valley, rear face, removal of existing front lower ground level window, widening of opening and installation of new sash window and upgrade and extension of heating and plumbing systems and redecoration.',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1580774400000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.25676775020613, 53.3087555004]},
#    'properties': {'ApplicationNumber': 'WEB1050/20',
#     'ApplicationStatus': 'Decision Notice Issued',
#     'Decision': 'APPLICATION DECLARED INVALID',
#     'DevelopmentDescription': 'On behalf of Aisling and Shane Barrett, Planning Permission is sought for works at 43 South Hill, Dartry, Dublin, D06 Y0E0. Works to include the installation of external insulation, the demolition of a section of the existing entrance wall, increasing the existing driveway entrance. These are proposed in conjunction with the previous planning application of no. WEB1745/19. Works to also include all associated site and landscaping works.',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1580428800000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.25457429941952, 53.3146336662499]},
#    'properties': {'ApplicationNumber': '2105/20',
#     'ApplicationStatus': 'Decision Notice Issued',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'PROTECTED STRUCTURE: planning permission for development consisting of revision to condition 3 of previously approved development Pl Reg 3589/19 at Kilfenora, 16, Temple Gardens, Rathmines, Dublin 6 D06 CP73 (A Protected Structure) to provide for new zinc clad dormer window to existing rear south facing return roof to allow for new shower room at 2nd floor landing level of existing house.',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1579737600000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.26455283397975, 53.3089604335342]},
#    'properties': {'ApplicationNumber': 'WEB1032/20',
#     'ApplicationStatus': 'Decision Notice Issued',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'Siobhan and Robert Tully intend to apply for development at 19 St Kevin’s Park, Dartry, Dublin 6. The development will consist of the refurbishment and extension of existing 2 storey semi detached property including the a) removal of single storey garage and kitchen to the side and rear, b) the construction of a new kitchen, dining and living area to the rear on ground floor, c) a new 2 storey extension to the side of the house with a bedroom, bathroom and living area and d) landscaping to the front and rear and all associated site works.',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1579651200000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.26409687338746, 53.3129026162975]},
#    'properties': {'ApplicationNumber': '2075/20',
#     'ApplicationStatus': 'Decision Appealed',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'Permission for the construction of a new single storey rear extension to Ardagh House, 1 Highfield Road, Dublin 6, D06 VE86.  Proposed works include the demolition of the existing rear extension to enable construction of the new single storey extension measuring 192m2 which provided six additional bedrooms, conversion of the existing garage measuring a total of 55m2, limited internal alterations to the existing guesthouse and the provision of 11 car parking spaces and 5 bike spaces.  Associated works will include external site services, drainage and landscaping as required to meet the requirements of the Local Authority.',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1579478400000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.26455283397975, 53.3089604335342]},
#    'properties': {'ApplicationNumber': 'WEB1023/20',
#     'ApplicationStatus': 'Decision Notice Issued',
#     'Decision': 'APPLICATION DECLARED INVALID',
#     'DevelopmentDescription': 'Siobhan and Robert Tully intend to apply for development at 19 St Kevin’s Park, Dartry, Dublin 6. The development will consist of the refurbishment and extension of existing 2 storey semi detached property including the \r\na) removal of single storey garage and kitchen to the side and rear, \r\nb) the construction of a new kitchen, dining and living area to the rear on ground floor, \r\nc) a new 2 storey extension to the side of the house with a bedroom, bathroom and living area and \r\nd) landscaping to the front and rear and all associated site works.',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1579046400000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.26455283397975, 53.3089604335342]},
#    'properties': {'ApplicationNumber': 'WEB1012/20',
#     'ApplicationStatus': 'Decision Notice Issued',
#     'Decision': 'APPLICATION DECLARED INVALID',
#     'DevelopmentDescription': 'Siobhan and Robert Tully intend to apply for development at 19 St Kevin’s Park, Dartry, Dublin 6. The development will consist of the refurbishment and extension of existing 2 storey semi detached property including the \r\na) removal of single storey garage and kitchen to the side and rear, \r\nb) the construction of a new kitchen, dining and living area to the rear on ground floor, \r\nc) a new 2 storey extension to the side of the house with a bedroom, bathroom and living area and \r\nd) landscaping to the front and rear and all associated site works.',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1578873600000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.25457429941952, 53.3146336662499]},
#    'properties': {'ApplicationNumber': '2014/20',
#     'ApplicationStatus': 'Decision Notice Issued',
#     'Decision': 'APPLICATION DECLARED INVALID',
#     'DevelopmentDescription': "PROTECTED STRUCTURE: Planning permission for development consisting of revision to condition 3 of previously approved development PL Reg 3589/19 at ‘Kilfenora', 16 Temple Gardens, Rathmines, Dublin 6 D06 CP73 (a Protected Structure) to provide for new zinc clad dormer window to existing rear south facing return roof to allow for new shower room at 2nd floor landing level of existing house.",
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1578268800000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.24134420405534, 53.304896387626]},
#    'properties': {'ApplicationNumber': 'D20A/0003',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'GRANT PERMISSION                        ',
#     'DevelopmentDescription': 'Permission for development. the development will consist of:',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1578268800000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.25676775020613, 53.3087555004]},
#    'properties': {'ApplicationNumber': 'WEB1745/19',
#     'ApplicationStatus': 'Decision Notice Issued',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'On behalf of Aisling and Shane Barrett, Planning Permission is sought for the refurbishment of the existing 4 -bedroom house, at 43 South Hill, Dartry, Dublin, D06 Y0E0. The proposed development will include the demolition of the existing front porch and the construction of a new porch to the front façade. The development will also include proposed new windows throughout, including the reconfiguration of the front and side façade. Works to include all associated site and landscaping works.',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1576713600000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.25486855005123, 53.314577958963]},
#    'properties': {'ApplicationNumber': '4756/19',
#     'ApplicationStatus': 'Decision Notice Issued',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'The proposed development will consist of modifications to the permitted extension, refurbishment and repair of the existing house pursuant to Reg Ref No. 3217/19 to include the following works: 1. The construction of a 9 sqm first floor side extension at the west side of the house to relocate en-suite and all associated works. 2. The widening of a side entrance door at ground floor level to incorporate a fixed glass panel.',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1576713600000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.25603407089208, 53.3152471036219]},
#    'properties': {'ApplicationNumber': '4751/19',
#     'ApplicationStatus': 'Decision Notice Issued',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'PROTECTED STRUCTURE: Works include the demolition of two-storey and single-storey extensions to the side and rear. The construction of a new single-storey extension to the side and rear. Internal alterations, refurbishment and decoration of the existing house. New mechanical and electrical services. Refurbishment of existing sash windows. The demolition of a brick screen wall and reconstruction on completion of the works.',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1576713600000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.2484542083158, 53.3012674006641]},
#    'properties': {'ApplicationNumber': 'D19B/0522',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'GRANT PERMISSION                        ',
#     'DevelopmentDescription': 'Permission for development at this site.  The development will consist of',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1576713600000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.24409049647911, 53.3101337058681]},
#    'properties': {'ApplicationNumber': 'D19A/0987',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'CLARIFICATION OF FURTHER INFORMATION    ',
#     'DevelopmentDescription': 'Permission is sought for the demolition of existing side conservatory',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1576540800000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.25226097102481, 53.3144503156741]},
#    'properties': {'ApplicationNumber': '4701/19',
#     'ApplicationStatus': 'Decision Notice Issued',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'The development will consist of the installation of twelve solar panels on the roof of the house.',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1576195200000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.25791731624039, 53.3053831190904]},
#    'properties': {'ApplicationNumber': 'D19B/0511',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'GRANT PERMISSION                        ',
#     'DevelopmentDescription': 'Permission for: The proposed development will consist of',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1576108800000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.24482975579802, 53.3043165173614]},
#    'properties': {'ApplicationNumber': 'D19A/0953',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'GRANT PERMISSION                        ',
#     'DevelopmentDescription': 'Permission for a vehicular entrance and provision',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1575849600000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.2570157912106, 53.3174237125072]},
#    'properties': {'ApplicationNumber': '4652/19',
#     'ApplicationStatus': 'Decision Notice Issued',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'PROTECTED STRUCTURE: Works will include demolition of single storey rear extension and boiler shed, the erection of a single storey extension to the rear and side, with 3 no. rooflights, comprising living, kitchen and dining areas and utility room. Internal alterations to existing house will include insertion of a family bathroom at first floor level, insertion of an en-suite shower room to rear first floor bedroom, conversion of existing second floor shower room to bedroom, removal of partition separating entrance hall from rear extension, reinstatement of original double doors joining front living room and dining rooms, enlarged door from entrance hall to front living room, insertion of new window in below-stairs w.c. in gable wall. In addition, works to upgrade the heating drainage and electrical services, repairs to existing windows, replacement of one no. PVC window to rear with timber sash window to match existing windows.',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1575849600000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.24350603351401, 53.3147623109993]},
#    'properties': {'ApplicationNumber': '4643/19',
#     'ApplicationStatus': 'Decision Notice Issued',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'The proposed development will consist of demolition of existing rear extension and the construction of new single storey extension with rooflights to rear of existing dwelling and all associated site works.',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dublin City Council',
#     'ReceivedDate': 1575590400000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.23853498627288, 53.3129640827458]},
#    'properties': {'ApplicationNumber': 'D19A/0949',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'GRANT PERMISSION                        ',
#     'DevelopmentDescription': 'Permission for development at the 0.022-hectare site, currently under constructi',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1575590400000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.2455191241129, 53.3035829188825]},
#    'properties': {'ApplicationNumber': 'D19A/0937',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'REQUEST ADDITIONAL INFORMATION          ',
#     'DevelopmentDescription': 'Permission for variation of planning condition no. 2 attached to the grant of pl',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1575331200000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.24029031075669, 53.3076893085702]},
#    'properties': {'ApplicationNumber': 'D19A/0905',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'GRANT PERMISSION & REFUSE PERMISSION    ',
# ...
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'works to the existing two storey dwelling house to include: a) construction of a',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1171843200000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.2594678149242, 53.3054744979459]},
#    'properties': {'ApplicationNumber': 'D07B/0140',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'attic conversion with roof windows to rear, gable window to side, and alteration',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1171584000000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.24390781882057, 53.310683517264]},
#    'properties': {'ApplicationNumber': 'D07B/0128',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'erection of a hardwood timber conservatory to the rear of the property          ',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1171411200000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.23647272844909, 53.3061838322523]},
#    'properties': {'ApplicationNumber': 'D07A/0201',
#     'ApplicationStatus': 'Appeal decided',
#     'Decision': 'REFUSE PERMISSION',
#     'DevelopmentDescription': 'demolition of two semi-detached 4 bed housesand construction of an apartment dev',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1171411200000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.23752129368142, 53.3062187639849]},
#    'properties': {'ApplicationNumber': 'D07B/0118',
#     'ApplicationStatus': 'Appeal decided',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'demolition of existing lean-to sun room and the construction of a dormer extensi',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1170979200000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.24954928927465, 53.3040756068122]},
#    'properties': {'ApplicationNumber': 'D07A/0153',
#     'ApplicationStatus': 'Appeal decided',
#     'Decision': 'REFUSE PERMISSION',
#     'DevelopmentDescription': '2no. two-bedroom residential apartments in two storey and single storey building',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1170374400000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.23819533083946, 53.3095414727721]},
#    'properties': {'ApplicationNumber': 'D07A/0138',
#     'ApplicationStatus': 'Appeal decided',
#     'Decision': 'REFUSE PERMISSION',
#     'DevelopmentDescription': 'removal of an existing garage and outhouses, and the building of a two storey ex',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1170201600000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.2470731497433, 53.3046210838289]},
#    'properties': {'ApplicationNumber': 'D07A/0082',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'Demolition of the existing single storey rear extension,                        ',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1169164800000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.24996442717421, 53.3040539107506]},
#    'properties': {'ApplicationNumber': 'D07A/0042',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'GRANT PERMISSION & REFUSE PERMISSION',
#     'DevelopmentDescription': 'retention of an existing single storey extension of 13.28sqm comprising of study',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1168560000000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.24445353180412, 53.3049968246013]},
#    'properties': {'ApplicationNumber': 'D07B/0021',
#     'ApplicationStatus': 'Appeal decided',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': '(1) alterations to roof profile, (2) the provision of dormer and bay windows to ',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1168473600000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.244578154836, 53.3049958161114]},
#    'properties': {'ApplicationNumber': 'D07B/0009',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'GRANT PERMISSION                        ',
#     'DevelopmentDescription': 'New dormer window to rear elevation and retention permission',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1168214400000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.24390773766866, 53.3106834468601]},
#    'properties': {'ApplicationNumber': 'D06B/1139',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'DECLARE INVALID (SITE NOTICE)',
#     'DevelopmentDescription': 'erection of a hardwood timber conservatory to the rear of the property          ',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1166745600000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.23565314609131, 53.3076510447905]},
#    'properties': {'ApplicationNumber': 'D06A/1956',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'REFUSE PERMISSION',
#     'DevelopmentDescription': 'demolition of garage and erection of new home office and garage',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1166659200000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.26067514195328, 53.3048076137661]},
#    'properties': {'ApplicationNumber': 'D06A/1884',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'GRANT PERMISSION FOR RETENTION',
#     'DevelopmentDescription': 'D00B/0849, for the alterations                                                  ',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1166400000000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.24954928927465, 53.3040756068122]},
#    'properties': {'ApplicationNumber': 'D06A/1775',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'DECLARE INVALID (SITE NOTICE)',
#     'DevelopmentDescription': '2no. two bedroom residential apartments in two storey and single storey building',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1165190400000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.24042528070638, 53.3095930542713]},
#    'properties': {'ApplicationNumber': 'D06B/1027',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'REFUSE PERMISSION',
#     'DevelopmentDescription': 'demolition of existing garage and single storey accomodation                    ',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1164585600000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.26034660767291, 53.3045054157511]},
#    'properties': {'ApplicationNumber': 'D06A/1638',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'For development consisting of revised front elevations to existing house        ',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1163376000000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.23895491935977, 53.3050045755965]},
#    'properties': {'ApplicationNumber': 'D06B/0983',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'For the provision of a new two-storey extension to the side                     ',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1163116800000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.24530378643107, 53.3044698846298]},
#    'properties': {'ApplicationNumber': 'D06A/1545',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'For alterations ot existing boundary wall to provide access for off street      ',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1161820800000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.24186638738033, 53.3042425269826]},
#    'properties': {'ApplicationNumber': 'D06A/1527',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'To build a 2 storey detached two bedroomed house on site at side.               ',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1161734400000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.24954032380536, 53.3052694604646]},
#    'properties': {'ApplicationNumber': 'PC/24/06',
#     'ApplicationStatus': None,
#     'Decision': 'GRANT APPROVAL',
#     'DevelopmentDescription': 'Refurbishment and extension                                                     ',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1161216000000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.2470731656596, 53.3046210615924]},
#    'properties': {'ApplicationNumber': 'D06A/1355',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'REFUSE PERMISSION',
#     'DevelopmentDescription': 'Demolition of the existing single storey rear extension, chimney and out-houses ',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1158796800000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.24589988367224, 53.303773073664]},
#    'properties': {'ApplicationNumber': 'D06A/1360',
#     'ApplicationStatus': 'Appeal decided',
#     'Decision': 'REFUSE PERMISSION',
#     'DevelopmentDescription': 'Construction of a 3 bedroom 2 storey and part single storey,',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1158796800000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.24815375190538, 53.3039983067465]},
#    'properties': {'ApplicationNumber': 'D06A/1332',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'Development at the rear consisting of the construction of a new single storey   ',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1158278400000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.24695555375196, 53.3040309415877]},
#    'properties': {'ApplicationNumber': 'D06A/1286',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'Demolition of existing first floor dormer window and garden wall                ',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1157587200000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.24194309611187, 53.3112542141347]},
#    'properties': {'ApplicationNumber': 'D06B/0760',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'Demolish the concrete flat roof to the existing side extension                  ',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1156118400000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.24038582365307, 53.3084136598633]},
#    'properties': {'ApplicationNumber': 'D06B/0745',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'GRANT PERMISSION FOR RETENTION',
#     'DevelopmentDescription': 'Retention sought for a single storey flat roofed extension                      ',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1155600000000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.25279681814631, 53.3065005464113]},
#    'properties': {'ApplicationNumber': 'D06A/1128',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'Construct a detached 4 bedroom, two storey house                                ',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1154563200000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.25130601849378, 53.3032504246934]},
#    'properties': {'ApplicationNumber': 'D06B/0702',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'REFUSE PERMISSION',
#     'DevelopmentDescription': 'Works to include, (a) construction of a two storey extension to the side & rear ',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1154390400000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.23753718006736, 53.3084017280532]},
#    'properties': {'ApplicationNumber': 'D06A/1022',
#     'ApplicationStatus': 'Appeal decided',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'Demolition of existing single storey house                                      ',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1153094400000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.23634491237426, 53.3097263928235]},
#    'properties': {'ApplicationNumber': 'D06B/0632',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'GRANT PERMISSION',
#     'DevelopmentDescription': 'Conversion and alteration of existing attached garage                           ',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1152576000000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.25252380402421, 53.3060946802977]},
#    'properties': {'ApplicationNumber': 'D06B/0605',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'GRANT PERMISSION                        ',
#     'DevelopmentDescription': 'Conversion of the existing attic space to a useable bedroom',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1152230400000}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.24352088496707, 53.3023564721808]},
#    'properties': {'ApplicationNumber': 'D06A/0944',
#     'ApplicationStatus': 'Decision made',
#     'Decision': 'GRANT PERMISSION                        ',
#     'DevelopmentDescription': 'Change of use from Warehousing to Offices,',
#     'LinkAppDetails': None,
#     'PlanningAuthority': 'Dun Laoghaire Rathdown County Council',
#     'ReceivedDate': 1151971200000}},
#   ...]}
